# %% [markdown]
# # Imports

# %%
import xgboost as xgb
import pandas as pd
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt
import dataframe_image as dfi
import sklearn.metrics as mtr
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.inspection import permutation_importance

# %% [markdown]
# Leitura do dados

# %%
df = pd.read_csv("rota32893.csv")
df
# Out:
#              data_partida         data_chegada  linha  tempo_viagem  \
# 0     2019-07-03 17:42:38  2019-07-03 18:20:59  32893          2301
# 1     2019-07-05 08:53:39  2019-07-05 09:23:33  32893          1794
# 2     2019-07-17 08:08:59  2019-07-17 08:47:22  32893          2303
# 3     2019-07-17 11:43:09  2019-07-17 12:20:55  32893          2266
# 4     2019-07-25 10:01:00  2019-07-25 10:35:59  32893          2099
# ...                   ...                  ...    ...           ...
# 5267  2019-09-29 19:47:39  2019-09-29 20:10:07  32893          1348
# 5268  2019-09-30 05:29:20  2019-09-30 06:18:38  32893          2958
# 5269  2019-09-30 07:54:52  2019-09-30 08:43:48  32893          2936
# 5270  2019-09-30 11:51:07  2019-09-30 12:19:58  32893          1731
# 5271  2019-09-30 17:10:57  2019-09-30 17:51:13  32893          2416
#
#       equipamento  dia_semana  partidaTimeStamp  qtdDiasAno  direcao  \
# 0            1351           3        1562186558         184        2
# 1            1353           5        1562327619         186        2
# 2            1353           3        1563361739         198        2
# 3            1353           3        1563374589         198        2
# 4            1353           4        1564059660         206        2
# ...           ...         ...               ...         ...      ...
# 5267          944           7        1569797259         272        2
# 5268          944           1        1569832160         273        2
# 5269          944           1        1569840892         273        2
# 5270          944           1        1569855067         273        2
# 5271          944           1        1569874257         273        2
#
#       tipo_dia  turno_dia  chegadaTimeStamp  hora  hora_dia
# 0            1          3        1562188859   NaN        17
# 1            1          2        1562329413   NaN         8
# 2            1          2        1563364042   NaN         8
# 3            1          2        1563376855   NaN        11
# 4            1          2        1564061759   NaN        10
# ...        ...        ...               ...   ...       ...
# 5267         1          4        1569798607   NaN        19
# 5268         1          2        1569835118   NaN         5
# 5269         1          2        1569843828   NaN         7
# 5270         1          2        1569856798   NaN        11
# 5271         1          3        1569876673   NaN        17
#
# [5272 rows x 14 columns]

# %% [markdown]
# # Exploração dos dados para a Escolha dos atributos

# %% [markdown]
# Gráfico de dispersão dos tempos de viagem ao longo dos dias

# %%
df.data_partida = pd.to_datetime(df.data_partida)

df_plot = df[["data_partida", "tempo_viagem"]]
df_plot = df_plot.set_index("data_partida")

plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.scatter(df_plot.index, df_plot["tempo_viagem"])

plt.subplot(2, 1, 2)
plt.scatter(df_plot[(df_plot.index > "2019-07-07") & (df_plot.index < "2019-07-14")].index, df_plot.loc[(df_plot.index > "2019-07-07") & (df_plot.index < "2019-07-14"), "tempo_viagem"])

plt.show()

# %% [markdown]
# Tabela de correlação entre os atributos do dataframe

# %%
df.corr()
# Out:
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_15788\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   linha  tempo_viagem  equipamento  dia_semana  \
# linha               NaN           NaN          NaN         NaN
# tempo_viagem        NaN      1.000000     0.000933   -0.107438
# equipamento         NaN      0.000933     1.000000    0.043130
# dia_semana          NaN     -0.107438     0.043130    1.000000
# partidaTimeStamp    NaN     -0.047102    -0.048824   -0.005862
# qtdDiasAno          NaN     -0.047254    -0.048510   -0.005899
# direcao             NaN           NaN          NaN         NaN
# tipo_dia            NaN     -0.043944    -0.005140    0.059663
# turno_dia           NaN      0.011854    -0.026185   -0.000630
# chegadaTimeStamp    NaN     -0.046688    -0.048824   -0.005907
# hora                NaN           NaN          NaN         NaN
# hora_dia            NaN      0.018935    -0.041909    0.004323
#
#                   partidaTimeStamp  qtdDiasAno  direcao  tipo_dia  turno_dia  \
# linha                          NaN         NaN      NaN       NaN        NaN
# tempo_viagem             -0.047102   -0.047254      NaN -0.043944   0.011854
# equipamento              -0.048824   -0.048510      NaN -0.005140  -0.026185
# dia_semana               -0.005862   -0.005899      NaN  0.059663  -0.000630
# partidaTimeStamp          1.000000    0.999970      NaN -0.009222   0.041895
# qtdDiasAno                0.999970    1.000000      NaN -0.009330   0.034703
# direcao                        NaN         NaN      NaN       NaN        NaN
# tipo_dia                 -0.009222   -0.009330      NaN  1.000000   0.011343
# turno_dia                 0.041895    0.034703      NaN  0.011343   1.000000
# chegadaTimeStamp          1.000000    0.999970      NaN -0.009241   0.041901
# hora                           NaN         NaN      NaN       NaN        NaN
# hora_dia                  0.046805    0.039107      NaN  0.013525   0.934388
#
#                   chegadaTimeStamp  hora  hora_dia
# linha                          NaN   NaN       NaN
# tempo_viagem             -0.046688   NaN  0.018935
# equipamento              -0.048824   NaN -0.041909
# dia_semana               -0.005907   NaN  0.004323
# partidaTimeStamp          1.000000   NaN  0.046805
# qtdDiasAno                0.999970   NaN  0.039107
# direcao                        NaN   NaN       NaN
# tipo_dia                 -0.009241   NaN  0.013525
# turno_dia                 0.041901   NaN  0.934388
# chegadaTimeStamp          1.000000   NaN  0.046814
# hora                           NaN   NaN       NaN
# hora_dia                  0.046814   NaN  1.000000

# %% [markdown]
# # Divisão em treino e teste

# %%
#Separação teste e treino
shape = int(df.shape[0] * 0.3)
df = df.sort_values(by=["data_partida"], ascending=False)
df_teste = df[:shape]
df_treino = df[shape:]

# %%
df_teste
# Out:
#             data_partida         data_chegada  linha  tempo_viagem  \
# 4080 2019-09-30 23:01:36  2019-09-30 23:29:58  32893          1702
# 5053 2019-09-30 22:40:17  2019-09-30 23:08:08  32893          1671
# 3908 2019-09-30 22:30:04  2019-09-30 22:54:17  32893          1453
# 4343 2019-09-30 21:50:20  2019-09-30 22:21:27  32893          1867
# 4410 2019-09-30 21:38:06  2019-09-30 22:04:36  32893          1590
# ...                  ...                  ...    ...           ...
# 3600 2019-09-03 06:12:43  2019-09-03 06:51:46  32893          2343
# 3819 2019-09-03 06:04:13  2019-09-03 06:51:09  32893          2816
# 4081 2019-09-03 05:47:59  2019-09-03 06:30:14  32893          2535
# 5028 2019-09-03 05:12:48  2019-09-03 05:52:33  32893          2385
# 3756 2019-09-02 23:12:31  2019-09-02 23:42:46  32893          1815
#
#       equipamento  dia_semana  partidaTimeStamp  qtdDiasAno  direcao  \
# 4080        51360           1        1569895296         273        2
# 5053        65409           1        1569894017         273        2
# 3908        51242           1        1569893404         273        2
# 4343        51548           1        1569891020         273        2
# 4410        51691           1        1569890286         273        2
# ...           ...         ...               ...         ...      ...
# 3600         1403           2        1567501963         246        2
# 3819        51209           2        1567501453         246        2
# 4081        51367           2        1567500479         246        2
# 5028        64449           2        1567498368         246        2
# 3756        50232           1        1567476751         245        2
#
#       tipo_dia  turno_dia  chegadaTimeStamp  hora  hora_dia
# 4080         1          4        1569896998   NaN        23
# 5053         1          4        1569895688   NaN        22
# 3908         1          4        1569894857   NaN        22
# 4343         1          4        1569892887   NaN        21
# 4410         1          4        1569891876   NaN        21
# ...        ...        ...               ...   ...       ...
# 3600         1          2        1567504306   NaN         6
# 3819         1          2        1567504269   NaN         6
# 4081         1          2        1567503014   NaN         5
# 5028         1          2        1567500753   NaN         5
# 3756         1          4        1567478566   NaN        23
#
# [1581 rows x 14 columns]

# %%
df_treino
# Out:
#             data_partida         data_chegada  linha  tempo_viagem  \
# 4795 2019-09-02 22:42:36  2019-09-02 23:10:47  32893          1691
# 4268 2019-09-02 21:52:12  2019-09-02 22:18:29  32893          1577
# 4441 2019-09-02 21:28:01  2019-09-02 21:53:47  32893          1546
# 3740 2019-09-02 21:09:50  2019-09-02 21:37:09  32893          1639
# 4114 2019-09-02 20:35:22  2019-09-02 21:05:00  32893          1778
# ...                  ...                  ...    ...           ...
# 119  2019-07-01 07:27:18  2019-07-01 08:02:41  32893          2123
# 915  2019-07-01 07:06:04  2019-07-01 07:54:36  32893          2912
# 721  2019-07-01 06:47:57  2019-07-01 07:24:00  32893          2163
# 118  2019-07-01 06:05:57  2019-07-01 06:45:00  32893          2343
# 914  2019-07-01 05:49:50  2019-07-01 06:28:45  32893          2335
#
#       equipamento  dia_semana  partidaTimeStamp  qtdDiasAno  direcao  \
# 4795          631           1        1567474956         245        2
# 4268        51548           1        1567471932         245        2
# 4441        51703           1        1567470481         245        2
# 3740        50221           1        1567469390         245        2
# 4114        51403           1        1567467322         245        2
# ...           ...         ...               ...         ...      ...
# 119         50276           1        1561976838         182        2
# 915         52642           1        1561975564         182        2
# 721         51888           1        1561974477         182        2
# 118         50276           1        1561971957         182        2
# 914         52642           1        1561970990         182        2
#
#       tipo_dia  turno_dia  chegadaTimeStamp  hora  hora_dia
# 4795         1          4        1567476647   NaN        22
# 4268         1          4        1567473509   NaN        21
# 4441         1          4        1567472027   NaN        21
# 3740         1          4        1567471029   NaN        21
# 4114         1          4        1567469100   NaN        20
# ...        ...        ...               ...   ...       ...
# 119          1          2        1561978961   NaN         7
# 915          1          2        1561978476   NaN         7
# 721          1          2        1561976640   NaN         6
# 118          1          2        1561974300   NaN         6
# 914          1          2        1561973325   NaN         5
#
# [3691 rows x 14 columns]

# %% [markdown]
# # Escolha dos atibutos e divisão dos atributos previsores da classe a ser prevista

# %% [markdown]
# Motivos das escolhas
#
#     data_partida foi desconsiderado pois era cobrado que a data fosse int
#     data_chegada e chegadaTimeStamp não fazem sentido pois nos dariam a "resposta"
#     linha e equipamento são apenas identificadores e não interferem nos dados
#     direcao apenas havia 1 valor (valor = 2)
#     turno_dia removido pois tem alta correlação com hora_dia
#     qtdDiasAno também tem uma alta correlação com os TimeStamps, mas resolvemos deixar para ver os resultados

# %%
x_teste = df_teste[["partidaTimeStamp", "dia_semana", "tipo_dia", "hora_dia","turno_dia"]]
y_teste = df_teste["tempo_viagem"]
x_treino = df_treino[["partidaTimeStamp", "dia_semana", "tipo_dia", "hora_dia","turno_dia"]]
y_treino = df_treino["tempo_viagem"]

# %% [markdown]
# # Modelagem e fit dos modelos

# %% [markdown]
# Possibilidades de hyper parâmetros para os modelos que serão criados

# %%
# Hyperparâmetros do XGBoosting
params_xgb = {
         "n_estimators": list(range(100, 1100, 100)), #Number of gradient boosted trees. Equivalent to number of boosting rounds
         "max_depth": list(range(2, 15)),#Maximum tree depth for base learners.
         "min_child_weight": list(range(1, 11)),#Minimum sum of instance weight(hessian) needed in a child.
         "learning_rate": [0.3, 0.2, 0.1, 0.05, 0.01, 0.005],#Boosting learning rate (xgb’s “eta”)
         "gamma": np.arange(0, 0.7, 0.1)#Minimum loss reduction required to make a further partition on a leaf node of the tree.
        }

# Hyperparâmetros do Random Forest
params_rf = {
         "n_estimators": list(range(100, 1100, 100)),#The number of trees in the forest.
         "bootstrap": [True, False],#Whether bootstrap samples are used when building trees. If False, the whole dataset is used to build each tree.
         "max_depth": list(range(2, 15)),#The maximum depth of the tree.
         "max_features": [1.0, "sqrt", "log2"],#The number of features to consider when looking for the best split:
         "min_samples_leaf": list(range(1, 11)),#The minimum number of samples required to split an internal node
         "min_samples_split": list(range(2, 11)),#The minimum number of samples required to be at a leaf node.
        }

# Hyperparâmetros do SVR
params_svr = {
         "C": [0.1, 1, 10, 100, 1000], #Regularization parameter. The strength of the regularization is inversely proportional to C
         "gamma": ["scale", "auto"],#Kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’.
        }

#Linear Regression não tem hyper parametrização

# %%
#Criação e fit do modelo XGB
modelo_xgb = xgb.XGBRegressor(early_stop_rounds = 100)
xgb_rand_search = RandomizedSearchCV(modelo_xgb, params_xgb, scoring="neg_mean_squared_error", n_iter=40, verbose=True, cv=10, n_jobs=-1, random_state=123)
xgb_rand_search.fit(x_treino, y_treino)
modelo_xgb = xgb_rand_search.best_estimator_

pprint(xgb_rand_search.best_params_)
modelo_xgb.fit(x_treino, y_treino, eval_set = [(x_treino, y_treino)])
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# [16:37:13] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "early_stop_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# {'gamma': 0.0,
#  'learning_rate': 0.005,
#  'max_depth': 3,
#  'min_child_weight': 5,
#  'n_estimators': 900}
# [16:37:14] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "early_stop_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:2895.44221
# [1]	validation_0-rmse:2882.31779
# [2]	validation_0-rmse:2869.26498
# [3]	validation_0-rmse:2856.28335
# [4]	validation_0-rmse:2843.37268
# [5]	validation_0-rmse:2830.53246
# [6]	validation_0-rmse:2817.76254
# [7]	validation_0-rmse:2805.06240
# [8]	validation_0-rmse:2792.43186
# [9]	validation_0-rmse:2779.87044
# [10]	validation_0-rmse:2767.37799
# [11]	validation_0-rmse:2754.95407
# [12]	validation_0-rmse:2742.59837
# [13]	validation_0-rmse:2730.31061
# [14]	validation_0-rmse:2718.09041
# [15]	validation_0-rmse:2705.93757
# [16]	validation_0-rmse:2693.85157
# [17]	validation_0-rmse:2681.83247
# [18]	validation_0-rmse:2669.87946
# [19]	validation_0-rmse:2657.99261
# [20]	validation_0-rmse:2646.17148
# [21]	validation_0-rmse:2634.41580
# [22]	validation_0-rmse:2622.72513
# [23]	validation_0-rmse:2611.09941
# [24]	validation_0-rmse:2599.53809
# [25]	validation_0-rmse:2588.04113
# [26]	validation_0-rmse:2576.60793
# [27]	validation_0-rmse:2565.23833
# [28]	validation_0-rmse:2553.93208
# [29]	validation_0-rmse:2542.68889
# [30]	validation_0-rmse:2531.50835
# [31]	validation_0-rmse:2520.39034
# [32]	validation_0-rmse:2509.33443
# [33]	validation_0-rmse:2498.34040
# [34]	validation_0-rmse:2487.40792
# [35]	validation_0-rmse:2476.53672
# [36]	validation_0-rmse:2465.72654
# [37]	validation_0-rmse:2454.97710
# [38]	validation_0-rmse:2444.28805
# [39]	validation_0-rmse:2433.65913
# [40]	validation_0-rmse:2423.09010
# [41]	validation_0-rmse:2412.58067
# [42]	validation_0-rmse:2402.13058
# [43]	validation_0-rmse:2391.73948
# [44]	validation_0-rmse:2381.40719
# [45]	validation_0-rmse:2371.13342
# [46]	validation_0-rmse:2360.91780
# [47]	validation_0-rmse:2350.76022
# [48]	validation_0-rmse:2340.66032
# [49]	validation_0-rmse:2330.61786
# [50]	validation_0-rmse:2320.63247
# [51]	validation_0-rmse:2310.69947
# [52]	validation_0-rmse:2300.82313
# [53]	validation_0-rmse:2291.00305
# [54]	validation_0-rmse:2281.23900
# [55]	validation_0-rmse:2271.53074
# [56]	validation_0-rmse:2261.87806
# [57]	validation_0-rmse:2252.28063
# [58]	validation_0-rmse:2242.73827
# [59]	validation_0-rmse:2233.25064
# [60]	validation_0-rmse:2223.81757
# [61]	validation_0-rmse:2214.43854
# [62]	validation_0-rmse:2205.11556
# [63]	validation_0-rmse:2195.84401
# [64]	validation_0-rmse:2186.62574
# [65]	validation_0-rmse:2177.46292
# [66]	validation_0-rmse:2168.35059
# [67]	validation_0-rmse:2159.29315
# [68]	validation_0-rmse:2150.28569
# [69]	validation_0-rmse:2141.33050
# [70]	validation_0-rmse:2132.42945
# [71]	validation_0-rmse:2123.57758
# [72]	validation_0-rmse:2114.77965
# [73]	validation_0-rmse:2106.03026
# [74]	validation_0-rmse:2097.33195
# [75]	validation_0-rmse:2088.68662
# [76]	validation_0-rmse:2080.08938
# [77]	validation_0-rmse:2071.54236
# [78]	validation_0-rmse:2063.04761
# [79]	validation_0-rmse:2054.60031
# [80]	validation_0-rmse:2046.20486
# [81]	validation_0-rmse:2037.85641
# [82]	validation_0-rmse:2029.55931
# [83]	validation_0-rmse:2021.30864
# [84]	validation_0-rmse:2013.10657
# [85]	validation_0-rmse:2004.95522
# [86]	validation_0-rmse:1996.84972
# [87]	validation_0-rmse:1988.79206
# [88]	validation_0-rmse:1980.78448
# [89]	validation_0-rmse:1972.82196
# [90]	validation_0-rmse:1964.90913
# [91]	validation_0-rmse:1957.04097
# [92]	validation_0-rmse:1949.21959
# [93]	validation_0-rmse:1941.44721
# [94]	validation_0-rmse:1933.71876
# [95]	validation_0-rmse:1926.03891
# [96]	validation_0-rmse:1918.40259
# [97]	validation_0-rmse:1910.81206
# [98]	validation_0-rmse:1903.26947
# [99]	validation_0-rmse:1895.76967
# [100]	validation_0-rmse:1888.31737
# [101]	validation_0-rmse:1880.90750
# [102]	validation_0-rmse:1873.54246
# [103]	validation_0-rmse:1866.22400
# [104]	validation_0-rmse:1858.94736
# [105]	validation_0-rmse:1851.71712
# [106]	validation_0-rmse:1844.52829
# [107]	validation_0-rmse:1837.38544
# [108]	validation_0-rmse:1830.28379
# [109]	validation_0-rmse:1823.22729
# [110]	validation_0-rmse:1816.21168
# [111]	validation_0-rmse:1809.24096
# [112]	validation_0-rmse:1802.31071
# [113]	validation_0-rmse:1795.42495
# [114]	validation_0-rmse:1788.57735
# [115]	validation_0-rmse:1781.77565
# [116]	validation_0-rmse:1775.01178
# [117]	validation_0-rmse:1768.29343
# [118]	validation_0-rmse:1761.61251
# [119]	validation_0-rmse:1754.97669
# [120]	validation_0-rmse:1748.37806
# [121]	validation_0-rmse:1741.82366
# [122]	validation_0-rmse:1735.30648
# [123]	validation_0-rmse:1728.83308
# [124]	validation_0-rmse:1722.39651
# [125]	validation_0-rmse:1716.00333
# [126]	validation_0-rmse:1709.64653
# [127]	validation_0-rmse:1703.33276
# [128]	validation_0-rmse:1697.05510
# [129]	validation_0-rmse:1690.81694
# [130]	validation_0-rmse:1684.62063
# [131]	validation_0-rmse:1678.46047
# [132]	validation_0-rmse:1672.34171
# [133]	validation_0-rmse:1666.25871
# [134]	validation_0-rmse:1660.21678
# [135]	validation_0-rmse:1654.21025
# [136]	validation_0-rmse:1648.24434
# [137]	validation_0-rmse:1642.31353
# [138]	validation_0-rmse:1636.42289
# [139]	validation_0-rmse:1630.56726
# [140]	validation_0-rmse:1624.75105
# [141]	validation_0-rmse:1618.96966
# [142]	validation_0-rmse:1613.22731
# [143]	validation_0-rmse:1607.51949
# [144]	validation_0-rmse:1601.85037
# [145]	validation_0-rmse:1596.21539
# [146]	validation_0-rmse:1590.61875
# [147]	validation_0-rmse:1585.05590
# [148]	validation_0-rmse:1579.53102
# [149]	validation_0-rmse:1574.03962
# [150]	validation_0-rmse:1568.58566
# [151]	validation_0-rmse:1563.16514
# [152]	validation_0-rmse:1557.78141
# [153]	validation_0-rmse:1552.43092
# [154]	validation_0-rmse:1547.11684
# [155]	validation_0-rmse:1541.83574
# [156]	validation_0-rmse:1536.59065
# [157]	validation_0-rmse:1531.37821
# [158]	validation_0-rmse:1526.20139
# [159]	validation_0-rmse:1521.05699
# [160]	validation_0-rmse:1515.94783
# [161]	validation_0-rmse:1510.87070
# [162]	validation_0-rmse:1505.82719
# [163]	validation_0-rmse:1500.81819
# [164]	validation_0-rmse:1495.84078
# [165]	validation_0-rmse:1490.89670
# [166]	validation_0-rmse:1485.98612
# [167]	validation_0-rmse:1481.10680
# [168]	validation_0-rmse:1476.25653
# [169]	validation_0-rmse:1471.43887
# [170]	validation_0-rmse:1466.65342
# [171]	validation_0-rmse:1461.90010
# [172]	validation_0-rmse:1457.17853
# [173]	validation_0-rmse:1452.48901
# [174]	validation_0-rmse:1447.83105
# [175]	validation_0-rmse:1443.20490
# [176]	validation_0-rmse:1438.61001
# [177]	validation_0-rmse:1434.04640
# [178]	validation_0-rmse:1429.51402
# [179]	validation_0-rmse:1425.01243
# [180]	validation_0-rmse:1420.54166
# [181]	validation_0-rmse:1416.10169
# [182]	validation_0-rmse:1411.69200
# [183]	validation_0-rmse:1407.30817
# [184]	validation_0-rmse:1402.95852
# [185]	validation_0-rmse:1398.63898
# [186]	validation_0-rmse:1394.34915
# [187]	validation_0-rmse:1390.08902
# [188]	validation_0-rmse:1385.85856
# [189]	validation_0-rmse:1381.65728
# [190]	validation_0-rmse:1377.48527
# [191]	validation_0-rmse:1373.34234
# [192]	validation_0-rmse:1369.22827
# [193]	validation_0-rmse:1365.13536
# [194]	validation_0-rmse:1361.07827
# [195]	validation_0-rmse:1357.04962
# [196]	validation_0-rmse:1353.04924
# [197]	validation_0-rmse:1349.07701
# [198]	validation_0-rmse:1345.13260
# [199]	validation_0-rmse:1341.21605
# [200]	validation_0-rmse:1337.32703
# [201]	validation_0-rmse:1333.45639
# [202]	validation_0-rmse:1329.62193
# [203]	validation_0-rmse:1325.81466
# [204]	validation_0-rmse:1322.03441
# [205]	validation_0-rmse:1318.28106
# [206]	validation_0-rmse:1314.55430
# [207]	validation_0-rmse:1310.85415
# [208]	validation_0-rmse:1307.18048
# [209]	validation_0-rmse:1303.52277
# [210]	validation_0-rmse:1299.90127
# [211]	validation_0-rmse:1296.30580
# [212]	validation_0-rmse:1292.73612
# [213]	validation_0-rmse:1289.12384
# [214]	validation_0-rmse:1285.59416
# [215]	validation_0-rmse:1282.09008
# [216]	validation_0-rmse:1278.55294
# [217]	validation_0-rmse:1275.09877
# [218]	validation_0-rmse:1271.66973
# [219]	validation_0-rmse:1268.26565
# [220]	validation_0-rmse:1264.82636
# [221]	validation_0-rmse:1261.41177
# [222]	validation_0-rmse:1258.07996
# [223]	validation_0-rmse:1254.71352
# [224]	validation_0-rmse:1251.42952
# [225]	validation_0-rmse:1248.11076
# [226]	validation_0-rmse:1244.81607
# [227]	validation_0-rmse:1241.60236
# [228]	validation_0-rmse:1238.35443
# [229]	validation_0-rmse:1235.18720
# [230]	validation_0-rmse:1232.04411
# [231]	validation_0-rmse:1228.92326
# [232]	validation_0-rmse:1225.82620
# [233]	validation_0-rmse:1222.75184
# [234]	validation_0-rmse:1219.68991
# [235]	validation_0-rmse:1216.65093
# [236]	validation_0-rmse:1213.64377
# [237]	validation_0-rmse:1210.64945
# [238]	validation_0-rmse:1207.68671
# [239]	validation_0-rmse:1204.74523
# [240]	validation_0-rmse:1201.81692
# [241]	validation_0-rmse:1198.91948
# [242]	validation_0-rmse:1196.04315
# [243]	validation_0-rmse:1193.17961
# [244]	validation_0-rmse:1190.34627
# [245]	validation_0-rmse:1187.53464
# [246]	validation_0-rmse:1184.73482
# [247]	validation_0-rmse:1181.96448
# [248]	validation_0-rmse:1179.21492
# [249]	validation_0-rmse:1176.47759
# [250]	validation_0-rmse:1173.76913
# [251]	validation_0-rmse:1171.07293
# [252]	validation_0-rmse:1168.39747
# [253]	validation_0-rmse:1165.74981
# [254]	validation_0-rmse:1163.12224
# [255]	validation_0-rmse:1160.50713
# [256]	validation_0-rmse:1157.91911
# [257]	validation_0-rmse:1155.35098
# [258]	validation_0-rmse:1152.79510
# [259]	validation_0-rmse:1150.26565
# [260]	validation_0-rmse:1147.75685
# [261]	validation_0-rmse:1145.25906
# [262]	validation_0-rmse:1142.78714
# [263]	validation_0-rmse:1140.33055
# [264]	validation_0-rmse:1137.89656
# [265]	validation_0-rmse:1135.48127
# [266]	validation_0-rmse:1133.08082
# [267]	validation_0-rmse:1130.70240
# [268]	validation_0-rmse:1128.34346
# [269]	validation_0-rmse:1125.99819
# [270]	validation_0-rmse:1123.67437
# [271]	validation_0-rmse:1121.36882
# [272]	validation_0-rmse:1119.07764
# [273]	validation_0-rmse:1116.80128
# [274]	validation_0-rmse:1114.51960
# [275]	validation_0-rmse:1112.26689
# [276]	validation_0-rmse:1110.04650
# [277]	validation_0-rmse:1107.81736
# [278]	validation_0-rmse:1105.61654
# [279]	validation_0-rmse:1103.42196
# [280]	validation_0-rmse:1101.27016
# [281]	validation_0-rmse:1099.12025
# [282]	validation_0-rmse:1096.97646
# [283]	validation_0-rmse:1094.87507
# [284]	validation_0-rmse:1092.77503
# [285]	validation_0-rmse:1090.68092
# [286]	validation_0-rmse:1088.62895
# [287]	validation_0-rmse:1086.56788
# [288]	validation_0-rmse:1084.53249
# [289]	validation_0-rmse:1082.52891
# [290]	validation_0-rmse:1080.51599
# [291]	validation_0-rmse:1078.54441
# [292]	validation_0-rmse:1076.56342
# [293]	validation_0-rmse:1074.62346
# [294]	validation_0-rmse:1072.67376
# [295]	validation_0-rmse:1070.76064
# [296]	validation_0-rmse:1068.86679
# [297]	validation_0-rmse:1066.96319
# [298]	validation_0-rmse:1065.09924
# [299]	validation_0-rmse:1063.22600
# [300]	validation_0-rmse:1061.39181
# [301]	validation_0-rmse:1059.54847
# [302]	validation_0-rmse:1057.74379
# [303]	validation_0-rmse:1055.95408
# [304]	validation_0-rmse:1054.15479
# [305]	validation_0-rmse:1052.39321
# [306]	validation_0-rmse:1050.62276
# [307]	validation_0-rmse:1048.88645
# [308]	validation_0-rmse:1047.16736
# [309]	validation_0-rmse:1045.43938
# [310]	validation_0-rmse:1043.74877
# [311]	validation_0-rmse:1042.04878
# [312]	validation_0-rmse:1040.38462
# [313]	validation_0-rmse:1038.71213
# [314]	validation_0-rmse:1037.07600
# [315]	validation_0-rmse:1035.45355
# [316]	validation_0-rmse:1033.82152
# [317]	validation_0-rmse:1032.22412
# [318]	validation_0-rmse:1030.61863
# [319]	validation_0-rmse:1029.04482
# [320]	validation_0-rmse:1027.46558
# [321]	validation_0-rmse:1025.91995
# [322]	validation_0-rmse:1024.38847
# [323]	validation_0-rmse:1022.84753
# [324]	validation_0-rmse:1021.33981
# [325]	validation_0-rmse:1019.82417
# [326]	validation_0-rmse:1018.34486
# [327]	validation_0-rmse:1016.87815
# [328]	validation_0-rmse:1015.39974
# [329]	validation_0-rmse:1013.93283
# [330]	validation_0-rmse:1012.50240
# [331]	validation_0-rmse:1011.08010
# [332]	validation_0-rmse:1009.64910
# [333]	validation_0-rmse:1008.25006
# [334]	validation_0-rmse:1006.86315
# [335]	validation_0-rmse:1005.46723
# [336]	validation_0-rmse:1004.10710
# [337]	validation_0-rmse:1002.75866
# [338]	validation_0-rmse:1001.41754
# [339]	validation_0-rmse:1000.06690
# [340]	validation_0-rmse:998.75222
# [341]	validation_0-rmse:997.42405
# [342]	validation_0-rmse:996.12697
# [343]	validation_0-rmse:994.82082
# [344]	validation_0-rmse:993.54975
# [345]	validation_0-rmse:992.28541
# [346]	validation_0-rmse:991.01145
# [347]	validation_0-rmse:989.76873
# [348]	validation_0-rmse:988.53579
# [349]	validation_0-rmse:987.29343
# [350]	validation_0-rmse:986.08558
# [351]	validation_0-rmse:984.88393
# [352]	validation_0-rmse:983.67238
# [353]	validation_0-rmse:982.49068
# [354]	validation_0-rmse:981.29963
# [355]	validation_0-rmse:980.13797
# [356]	validation_0-rmse:978.99041
# [357]	validation_0-rmse:977.82895
# [358]	validation_0-rmse:976.69638
# [359]	validation_0-rmse:975.57802
# [360]	validation_0-rmse:974.44561
# [361]	validation_0-rmse:973.34643
# [362]	validation_0-rmse:972.25219
# [363]	validation_0-rmse:971.14808
# [364]	validation_0-rmse:970.07695
# [365]	validation_0-rmse:969.01026
# [366]	validation_0-rmse:967.93382
# [367]	validation_0-rmse:966.89007
# [368]	validation_0-rmse:965.82758
# [369]	validation_0-rmse:964.77810
# [370]	validation_0-rmse:963.76106
# [371]	validation_0-rmse:962.74822
# [372]	validation_0-rmse:961.72514
# [373]	validation_0-rmse:960.73424
# [374]	validation_0-rmse:959.74705
# [375]	validation_0-rmse:958.74983
# [376]	validation_0-rmse:957.78446
# [377]	validation_0-rmse:956.79948
# [378]	validation_0-rmse:955.82737
# [379]	validation_0-rmse:954.80055
# [380]	validation_0-rmse:953.86806
# [381]	validation_0-rmse:952.91588
# [382]	validation_0-rmse:951.91430
# [383]	validation_0-rmse:951.00585
# [384]	validation_0-rmse:950.02088
# [385]	validation_0-rmse:949.10145
# [386]	validation_0-rmse:948.19210
# [387]	validation_0-rmse:947.23127
# [388]	validation_0-rmse:946.36135
# [389]	validation_0-rmse:945.41651
# [390]	validation_0-rmse:944.53555
# [391]	validation_0-rmse:943.60683
# [392]	validation_0-rmse:942.74198
# [393]	validation_0-rmse:941.90898
# [394]	validation_0-rmse:940.96744
# [395]	validation_0-rmse:940.06832
# [396]	validation_0-rmse:939.17731
# [397]	validation_0-rmse:938.34815
# [398]	validation_0-rmse:937.53490
# [399]	validation_0-rmse:936.74398
# [400]	validation_0-rmse:935.94487
# [401]	validation_0-rmse:935.16790
# [402]	validation_0-rmse:934.28252
# [403]	validation_0-rmse:933.44089
# [404]	validation_0-rmse:932.68396
# [405]	validation_0-rmse:931.91880
# [406]	validation_0-rmse:931.15057
# [407]	validation_0-rmse:930.39873
# [408]	validation_0-rmse:929.66077
# [409]	validation_0-rmse:928.91213
# [410]	validation_0-rmse:928.17953
# [411]	validation_0-rmse:927.46761
# [412]	validation_0-rmse:926.74781
# [413]	validation_0-rmse:926.04852
# [414]	validation_0-rmse:925.34133
# [415]	validation_0-rmse:924.62978
# [416]	validation_0-rmse:923.92163
# [417]	validation_0-rmse:923.23264
# [418]	validation_0-rmse:922.56334
# [419]	validation_0-rmse:921.78406
# [420]	validation_0-rmse:921.12651
# [421]	validation_0-rmse:920.39798
# [422]	validation_0-rmse:919.73842
# [423]	validation_0-rmse:919.07374
# [424]	validation_0-rmse:918.42573
# [425]	validation_0-rmse:917.79639
# [426]	validation_0-rmse:917.14833
# [427]	validation_0-rmse:916.51707
# [428]	validation_0-rmse:915.87636
# [429]	validation_0-rmse:915.26889
# [430]	validation_0-rmse:914.65392
# [431]	validation_0-rmse:914.05726
# [432]	validation_0-rmse:913.34974
# [433]	validation_0-rmse:912.68817
# [434]	validation_0-rmse:912.10099
# [435]	validation_0-rmse:911.51245
# [436]	validation_0-rmse:910.91746
# [437]	validation_0-rmse:910.33930
# [438]	validation_0-rmse:909.77838
# [439]	validation_0-rmse:909.10695
# [440]	validation_0-rmse:908.54996
# [441]	validation_0-rmse:907.99172
# [442]	validation_0-rmse:907.42640
# [443]	validation_0-rmse:906.88990
# [444]	validation_0-rmse:906.34616
# [445]	validation_0-rmse:905.81928
# [446]	validation_0-rmse:905.28519
# [447]	validation_0-rmse:904.74339
# [448]	validation_0-rmse:904.21871
# [449]	validation_0-rmse:903.71013
# [450]	validation_0-rmse:903.09047
# [451]	validation_0-rmse:902.51728
# [452]	validation_0-rmse:902.01633
# [453]	validation_0-rmse:901.51427
# [454]	validation_0-rmse:901.00401
# [455]	validation_0-rmse:900.51085
# [456]	validation_0-rmse:900.03282
# [457]	validation_0-rmse:899.44420
# [458]	validation_0-rmse:898.96908
# [459]	validation_0-rmse:898.49296
# [460]	validation_0-rmse:898.02639
# [461]	validation_0-rmse:897.54555
# [462]	validation_0-rmse:896.97806
# [463]	validation_0-rmse:896.45700
# [464]	validation_0-rmse:896.00650
# [465]	validation_0-rmse:895.55482
# [466]	validation_0-rmse:895.11762
# [467]	validation_0-rmse:894.65268
# [468]	validation_0-rmse:894.19066
# [469]	validation_0-rmse:893.74092
# [470]	validation_0-rmse:893.30845
# [471]	validation_0-rmse:892.89013
# [472]	validation_0-rmse:892.44393
# [473]	validation_0-rmse:892.00985
# [474]	validation_0-rmse:891.59228
# [475]	validation_0-rmse:891.18349
# [476]	validation_0-rmse:890.75222
# [477]	validation_0-rmse:890.33254
# [478]	validation_0-rmse:889.92938
# [479]	validation_0-rmse:889.53978
# [480]	validation_0-rmse:889.12287
# [481]	validation_0-rmse:888.71906
# [482]	validation_0-rmse:888.30932
# [483]	validation_0-rmse:887.93338
# [484]	validation_0-rmse:887.48984
# [485]	validation_0-rmse:887.09039
# [486]	validation_0-rmse:886.70142
# [487]	validation_0-rmse:886.30885
# [488]	validation_0-rmse:885.87905
# [489]	validation_0-rmse:885.50212
# [490]	validation_0-rmse:885.11930
# [491]	validation_0-rmse:884.76891
# [492]	validation_0-rmse:884.39274
# [493]	validation_0-rmse:884.02631
# [494]	validation_0-rmse:883.65658
# [495]	validation_0-rmse:883.24918
# [496]	validation_0-rmse:882.88582
# [497]	validation_0-rmse:882.55352
# [498]	validation_0-rmse:882.20225
# [499]	validation_0-rmse:881.84798
# [500]	validation_0-rmse:881.45590
# [501]	validation_0-rmse:881.10770
# [502]	validation_0-rmse:880.77010
# [503]	validation_0-rmse:880.42789
# [504]	validation_0-rmse:880.11546
# [505]	validation_0-rmse:879.77783
# [506]	validation_0-rmse:879.40332
# [507]	validation_0-rmse:879.08008
# [508]	validation_0-rmse:878.75173
# [509]	validation_0-rmse:878.45277
# [510]	validation_0-rmse:878.13009
# [511]	validation_0-rmse:877.81547
# [512]	validation_0-rmse:877.45764
# [513]	validation_0-rmse:877.14289
# [514]	validation_0-rmse:876.85685
# [515]	validation_0-rmse:876.54758
# [516]	validation_0-rmse:876.24583
# [517]	validation_0-rmse:875.90107
# [518]	validation_0-rmse:875.59945
# [519]	validation_0-rmse:875.30070
# [520]	validation_0-rmse:875.01091
# [521]	validation_0-rmse:874.71727
# [522]	validation_0-rmse:874.45049
# [523]	validation_0-rmse:874.12047
# [524]	validation_0-rmse:873.83411
# [525]	validation_0-rmse:873.55424
# [526]	validation_0-rmse:873.27274
# [527]	validation_0-rmse:873.01744
# [528]	validation_0-rmse:872.74082
# [529]	validation_0-rmse:872.46999
# [530]	validation_0-rmse:872.15637
# [531]	validation_0-rmse:871.88647
# [532]	validation_0-rmse:871.62450
# [533]	validation_0-rmse:871.35923
# [534]	validation_0-rmse:871.11907
# [535]	validation_0-rmse:870.81660
# [536]	validation_0-rmse:870.55786
# [537]	validation_0-rmse:870.30459
# [538]	validation_0-rmse:870.05022
# [539]	validation_0-rmse:869.82030
# [540]	validation_0-rmse:869.57033
# [541]	validation_0-rmse:869.32518
# [542]	validation_0-rmse:869.03748
# [543]	validation_0-rmse:868.79356
# [544]	validation_0-rmse:868.57350
# [545]	validation_0-rmse:868.33377
# [546]	validation_0-rmse:868.09849
# [547]	validation_0-rmse:867.82079
# [548]	validation_0-rmse:867.58686
# [549]	validation_0-rmse:867.35520
# [550]	validation_0-rmse:867.12947
# [551]	validation_0-rmse:866.90171
# [552]	validation_0-rmse:866.69630
# [553]	validation_0-rmse:866.43001
# [554]	validation_0-rmse:866.20779
# [555]	validation_0-rmse:865.98915
# [556]	validation_0-rmse:865.72866
# [557]	validation_0-rmse:865.51172
# [558]	validation_0-rmse:865.31667
# [559]	validation_0-rmse:865.10345
# [560]	validation_0-rmse:864.89524
# [561]	validation_0-rmse:864.64363
# [562]	validation_0-rmse:864.39431
# [563]	validation_0-rmse:864.18765
# [564]	validation_0-rmse:863.98625
# [565]	validation_0-rmse:863.74236
# [566]	validation_0-rmse:863.54057
# [567]	validation_0-rmse:863.35997
# [568]	validation_0-rmse:863.16162
# [569]	validation_0-rmse:862.92432
# [570]	validation_0-rmse:862.72930
# [571]	validation_0-rmse:862.54955
# [572]	validation_0-rmse:862.35779
# [573]	validation_0-rmse:862.18623
# [574]	validation_0-rmse:861.99774
# [575]	validation_0-rmse:861.81075
# [576]	validation_0-rmse:861.58415
# [577]	validation_0-rmse:861.40006
# [578]	validation_0-rmse:861.23571
# [579]	validation_0-rmse:861.01381
# [580]	validation_0-rmse:860.83412
# [581]	validation_0-rmse:860.65571
# [582]	validation_0-rmse:860.43856
# [583]	validation_0-rmse:860.26304
# [584]	validation_0-rmse:860.10685
# [585]	validation_0-rmse:859.93429
# [586]	validation_0-rmse:859.76445
# [587]	validation_0-rmse:859.55430
# [588]	validation_0-rmse:859.38576
# [589]	validation_0-rmse:859.23254
# [590]	validation_0-rmse:859.06679
# [591]	validation_0-rmse:858.91957
# [592]	validation_0-rmse:858.71617
# [593]	validation_0-rmse:858.55433
# [594]	validation_0-rmse:858.39266
# [595]	validation_0-rmse:858.19349
# [596]	validation_0-rmse:858.03535
# [597]	validation_0-rmse:857.89539
# [598]	validation_0-rmse:857.73525
# [599]	validation_0-rmse:857.54116
# [600]	validation_0-rmse:857.38361
# [601]	validation_0-rmse:857.23018
# [602]	validation_0-rmse:857.04003
# [603]	validation_0-rmse:856.88603
# [604]	validation_0-rmse:856.75400
# [605]	validation_0-rmse:856.60254
# [606]	validation_0-rmse:856.44452
# [607]	validation_0-rmse:856.29954
# [608]	validation_0-rmse:856.11641
# [609]	validation_0-rmse:855.97376
# [610]	validation_0-rmse:855.82031
# [611]	validation_0-rmse:855.69188
# [612]	validation_0-rmse:855.54829
# [613]	validation_0-rmse:855.39829
# [614]	validation_0-rmse:855.25860
# [615]	validation_0-rmse:855.08303
# [616]	validation_0-rmse:854.94364
# [617]	validation_0-rmse:854.79790
# [618]	validation_0-rmse:854.65355
# [619]	validation_0-rmse:854.51749
# [620]	validation_0-rmse:854.38544
# [621]	validation_0-rmse:854.24426
# [622]	validation_0-rmse:854.12988
# [623]	validation_0-rmse:853.99783
# [624]	validation_0-rmse:853.85979
# [625]	validation_0-rmse:853.72996
# [626]	validation_0-rmse:853.59413
# [627]	validation_0-rmse:853.46639
# [628]	validation_0-rmse:853.30298
# [629]	validation_0-rmse:853.17687
# [630]	validation_0-rmse:853.04483
# [631]	validation_0-rmse:852.93484
# [632]	validation_0-rmse:852.80485
# [633]	validation_0-rmse:852.68253
# [634]	validation_0-rmse:852.55462
# [635]	validation_0-rmse:852.43361
# [636]	validation_0-rmse:852.31404
# [637]	validation_0-rmse:852.18891
# [638]	validation_0-rmse:852.08793
# [639]	validation_0-rmse:851.97113
# [640]	validation_0-rmse:851.84869
# [641]	validation_0-rmse:851.72739
# [642]	validation_0-rmse:851.61184
# [643]	validation_0-rmse:851.46095
# [644]	validation_0-rmse:851.34816
# [645]	validation_0-rmse:851.22834
# [646]	validation_0-rmse:851.11740
# [647]	validation_0-rmse:851.01999
# [648]	validation_0-rmse:850.90272
# [649]	validation_0-rmse:850.79350
# [650]	validation_0-rmse:850.68402
# [651]	validation_0-rmse:850.53961
# [652]	validation_0-rmse:850.39659
# [653]	validation_0-rmse:850.29081
# [654]	validation_0-rmse:850.17798
# [655]	validation_0-rmse:850.08552
# [656]	validation_0-rmse:849.98208
# [657]	validation_0-rmse:849.87164
# [658]	validation_0-rmse:849.78480
# [659]	validation_0-rmse:849.68369
# [660]	validation_0-rmse:849.57553
# [661]	validation_0-rmse:849.46836
# [662]	validation_0-rmse:849.36693
# [663]	validation_0-rmse:849.27648
# [664]	validation_0-rmse:849.19351
# [665]	validation_0-rmse:849.09645
# [666]	validation_0-rmse:848.99259
# [667]	validation_0-rmse:848.88970
# [668]	validation_0-rmse:848.79198
# [669]	validation_0-rmse:848.66026
# [670]	validation_0-rmse:848.56641
# [671]	validation_0-rmse:848.46617
# [672]	validation_0-rmse:848.38141
# [673]	validation_0-rmse:848.30367
# [674]	validation_0-rmse:848.20541
# [675]	validation_0-rmse:848.11484
# [676]	validation_0-rmse:848.02178
# [677]	validation_0-rmse:847.92550
# [678]	validation_0-rmse:847.84422
# [679]	validation_0-rmse:847.76979
# [680]	validation_0-rmse:847.67538
# [681]	validation_0-rmse:847.58702
# [682]	validation_0-rmse:847.49915
# [683]	validation_0-rmse:847.37612
# [684]	validation_0-rmse:847.29056
# [685]	validation_0-rmse:847.21931
# [686]	validation_0-rmse:847.12819
# [687]	validation_0-rmse:847.04448
# [688]	validation_0-rmse:846.95474
# [689]	validation_0-rmse:846.86875
# [690]	validation_0-rmse:846.74975
# [691]	validation_0-rmse:846.66819
# [692]	validation_0-rmse:846.58066
# [693]	validation_0-rmse:846.51329
# [694]	validation_0-rmse:846.43349
# [695]	validation_0-rmse:846.34767
# [696]	validation_0-rmse:846.26265
# [697]	validation_0-rmse:846.19120
# [698]	validation_0-rmse:846.11227
# [699]	validation_0-rmse:846.04771
# [700]	validation_0-rmse:845.97093
# [701]	validation_0-rmse:845.88835
# [702]	validation_0-rmse:845.80654
# [703]	validation_0-rmse:845.72950
# [704]	validation_0-rmse:845.65500
# [705]	validation_0-rmse:845.54358
# [706]	validation_0-rmse:845.43317
# [707]	validation_0-rmse:845.35961
# [708]	validation_0-rmse:845.29892
# [709]	validation_0-rmse:845.22648
# [710]	validation_0-rmse:845.14817
# [711]	validation_0-rmse:845.07199
# [712]	validation_0-rmse:844.99927
# [713]	validation_0-rmse:844.89216
# [714]	validation_0-rmse:844.82196
# [715]	validation_0-rmse:844.74745
# [716]	validation_0-rmse:844.67343
# [717]	validation_0-rmse:844.61622
# [718]	validation_0-rmse:844.54782
# [719]	validation_0-rmse:844.47379
# [720]	validation_0-rmse:844.40136
# [721]	validation_0-rmse:844.33216
# [722]	validation_0-rmse:844.26031
# [723]	validation_0-rmse:844.15745
# [724]	validation_0-rmse:844.09292
# [725]	validation_0-rmse:844.03861
# [726]	validation_0-rmse:843.93728
# [727]	validation_0-rmse:843.86738
# [728]	validation_0-rmse:843.80282
# [729]	validation_0-rmse:843.73386
# [730]	validation_0-rmse:843.66555
# [731]	validation_0-rmse:843.60958
# [732]	validation_0-rmse:843.54667
# [733]	validation_0-rmse:843.47898
# [734]	validation_0-rmse:843.41225
# [735]	validation_0-rmse:843.34842
# [736]	validation_0-rmse:843.29768
# [737]	validation_0-rmse:843.23148
# [738]	validation_0-rmse:843.16621
# [739]	validation_0-rmse:843.11127
# [740]	validation_0-rmse:843.04839
# [741]	validation_0-rmse:842.99927
# [742]	validation_0-rmse:842.93980
# [743]	validation_0-rmse:842.87479
# [744]	validation_0-rmse:842.81081
# [745]	validation_0-rmse:842.74809
# [746]	validation_0-rmse:842.68786
# [747]	validation_0-rmse:842.62720
# [748]	validation_0-rmse:842.53339
# [749]	validation_0-rmse:842.47099
# [750]	validation_0-rmse:842.41404
# [751]	validation_0-rmse:842.35317
# [752]	validation_0-rmse:842.30710
# [753]	validation_0-rmse:842.25127
# [754]	validation_0-rmse:842.19148
# [755]	validation_0-rmse:842.13090
# [756]	validation_0-rmse:842.07289
# [757]	validation_0-rmse:842.02332
# [758]	validation_0-rmse:841.96336
# [759]	validation_0-rmse:841.90404
# [760]	validation_0-rmse:841.85760
# [761]	validation_0-rmse:841.80410
# [762]	validation_0-rmse:841.74685
# [763]	validation_0-rmse:841.68877
# [764]	validation_0-rmse:841.63224
# [765]	validation_0-rmse:841.57795
# [766]	validation_0-rmse:841.53077
# [767]	validation_0-rmse:841.48851
# [768]	validation_0-rmse:841.43699
# [769]	validation_0-rmse:841.38180
# [770]	validation_0-rmse:841.32548
# [771]	validation_0-rmse:841.27103
# [772]	validation_0-rmse:841.21808
# [773]	validation_0-rmse:841.16415
# [774]	validation_0-rmse:841.07763
# [775]	validation_0-rmse:841.02794
# [776]	validation_0-rmse:840.97309
# [777]	validation_0-rmse:840.91870
# [778]	validation_0-rmse:840.87888
# [779]	validation_0-rmse:840.83032
# [780]	validation_0-rmse:840.77826
# [781]	validation_0-rmse:840.72469
# [782]	validation_0-rmse:840.67313
# [783]	validation_0-rmse:840.63000
# [784]	validation_0-rmse:840.57897
# [785]	validation_0-rmse:840.54065
# [786]	validation_0-rmse:840.49445
# [787]	validation_0-rmse:840.44225
# [788]	validation_0-rmse:840.39224
# [789]	validation_0-rmse:840.34224
# [790]	validation_0-rmse:840.30066
# [791]	validation_0-rmse:840.26359
# [792]	validation_0-rmse:840.21254
# [793]	validation_0-rmse:840.16718
# [794]	validation_0-rmse:840.11849
# [795]	validation_0-rmse:840.06879
# [796]	validation_0-rmse:840.01969
# [797]	validation_0-rmse:839.97531
# [798]	validation_0-rmse:839.92780
# [799]	validation_0-rmse:839.87816
# [800]	validation_0-rmse:839.82746
# [801]	validation_0-rmse:839.78801
# [802]	validation_0-rmse:839.75075
# [803]	validation_0-rmse:839.70430
# [804]	validation_0-rmse:839.65857
# [805]	validation_0-rmse:839.61286
# [806]	validation_0-rmse:839.56458
# [807]	validation_0-rmse:839.53035
# [808]	validation_0-rmse:839.48828
# [809]	validation_0-rmse:839.44295
# [810]	validation_0-rmse:839.39805
# [811]	validation_0-rmse:839.35078
# [812]	validation_0-rmse:839.30249
# [813]	validation_0-rmse:839.26520
# [814]	validation_0-rmse:839.21994
# [815]	validation_0-rmse:839.17241
# [816]	validation_0-rmse:839.13577
# [817]	validation_0-rmse:839.10319
# [818]	validation_0-rmse:839.05963
# [819]	validation_0-rmse:839.01978
# [820]	validation_0-rmse:838.97535
# [821]	validation_0-rmse:838.92975
# [822]	validation_0-rmse:838.88364
# [823]	validation_0-rmse:838.84999
# [824]	validation_0-rmse:838.80777
# [825]	validation_0-rmse:838.77884
# [826]	validation_0-rmse:838.73419
# [827]	validation_0-rmse:838.68911
# [828]	validation_0-rmse:838.64764
# [829]	validation_0-rmse:838.61935
# [830]	validation_0-rmse:838.57497
# [831]	validation_0-rmse:838.53103
# [832]	validation_0-rmse:838.49031
# [833]	validation_0-rmse:838.45618
# [834]	validation_0-rmse:838.41377
# [835]	validation_0-rmse:838.37053
# [836]	validation_0-rmse:838.32750
# [837]	validation_0-rmse:838.30037
# [838]	validation_0-rmse:838.26057
# [839]	validation_0-rmse:838.21818
# [840]	validation_0-rmse:838.19153
# [841]	validation_0-rmse:838.14967
# [842]	validation_0-rmse:838.11056
# [843]	validation_0-rmse:838.06855
# [844]	validation_0-rmse:838.04244
# [845]	validation_0-rmse:838.00134
# [846]	validation_0-rmse:837.96287
# [847]	validation_0-rmse:837.92228
# [848]	validation_0-rmse:837.89673
# [849]	validation_0-rmse:837.85881
# [850]	validation_0-rmse:837.81542
# [851]	validation_0-rmse:837.77553
# [852]	validation_0-rmse:837.75048
# [853]	validation_0-rmse:837.71318
# [854]	validation_0-rmse:837.67389
# [855]	validation_0-rmse:837.63364
# [856]	validation_0-rmse:837.60906
# [857]	validation_0-rmse:837.57036
# [858]	validation_0-rmse:837.53378
# [859]	validation_0-rmse:837.49554
# [860]	validation_0-rmse:837.47144
# [861]	validation_0-rmse:837.42953
# [862]	validation_0-rmse:837.39351
# [863]	validation_0-rmse:837.36981
# [864]	validation_0-rmse:837.33230
# [865]	validation_0-rmse:837.29532
# [866]	validation_0-rmse:837.25412
# [867]	validation_0-rmse:837.21859
# [868]	validation_0-rmse:837.19543
# [869]	validation_0-rmse:837.15866
# [870]	validation_0-rmse:837.12374
# [871]	validation_0-rmse:837.08741
# [872]	validation_0-rmse:837.06466
# [873]	validation_0-rmse:837.02433
# [874]	validation_0-rmse:836.98994
# [875]	validation_0-rmse:836.95421
# [876]	validation_0-rmse:836.93154
# [877]	validation_0-rmse:836.90253
# [878]	validation_0-rmse:836.86867
# [879]	validation_0-rmse:836.83354
# [880]	validation_0-rmse:836.79400
# [881]	validation_0-rmse:836.77216
# [882]	validation_0-rmse:836.73751
# [883]	validation_0-rmse:836.70423
# [884]	validation_0-rmse:836.66749
# [885]	validation_0-rmse:836.63334
# [886]	validation_0-rmse:836.59977
# [887]	validation_0-rmse:836.57850
# [888]	validation_0-rmse:836.54580
# [889]	validation_0-rmse:836.51220
# [890]	validation_0-rmse:836.49100
# [891]	validation_0-rmse:836.45269
# [892]	validation_0-rmse:836.42046
# [893]	validation_0-rmse:836.38741
# [894]	validation_0-rmse:836.36677
# [895]	validation_0-rmse:836.33411
# [896]	validation_0-rmse:836.30236
# [897]	validation_0-rmse:836.28184
# [898]	validation_0-rmse:836.24963
# [899]	validation_0-rmse:836.21826
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stop_rounds=100, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=0.0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=3, max_leaves=0,
#              min_child_weight=5, missing=nan, monotone_constraints='()',
#              n_estimators=900, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=0, reg_alpha=0, ...)

# %%
#Criação e fit do modelo XGB
modelo_rf = RandomForestRegressor()
rf_rand_search = RandomizedSearchCV(modelo_rf, params_rf, scoring="neg_mean_squared_error", n_iter=40, verbose=True, cv=10, n_jobs=-1, random_state=123)
rf_rand_search.fit(x_treino, y_treino)
modelo_rf = rf_rand_search.best_estimator_

pprint(rf_rand_search.best_params_)
modelo_rf.fit(x_treino, y_treino)
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# {'bootstrap': True,
#  'max_depth': 11,
#  'max_features': 'log2',
#  'min_samples_leaf': 6,
#  'min_samples_split': 9,
#  'n_estimators': 700}
# RandomForestRegressor(max_depth=11, max_features='log2', min_samples_leaf=6,
#                       min_samples_split=9, n_estimators=700)

# %%
#Criação e fit do modelo XGB
modelo_svr = SVR(kernel = 'rbf')
svr_rand_search = RandomizedSearchCV(modelo_svr, params_svr, scoring="neg_mean_squared_error", n_iter=10, verbose=True, cv=10, n_jobs=-1, random_state=123)
svr_rand_search.fit(x_treino, y_treino)
modelo_svr = svr_rand_search.best_estimator_

pprint(svr_rand_search.best_params_)
modelo_svr.fit(x_treino, y_treino)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'C': 1000, 'gamma': 'auto'}
# SVR(C=1000, gamma='auto')

# %%
#Criação e fit do modelo XGB
modelo_lr = LinearRegression()
modelo_lr.fit(x_treino, y_treino)
# Out:
# LinearRegression()

# %% [markdown]
# # Métricas

# %% [markdown]
# Importância dos atributos

# %%
fi_xgb = pd.DataFrame(data=modelo_xgb.feature_importances_, index=modelo_xgb.feature_names_in_, columns=["importance"])
fi_xgb.sort_values("importance").plot(kind="barh", title="Importância Dados XGB")
# Out:
# <AxesSubplot: title={'center': 'Importância Dados XGB'}>

# %%
fi_rf = pd.DataFrame(data=modelo_rf.feature_importances_, index=x_treino.columns, columns=["importance"])
fi_rf.sort_values("importance").plot(kind="barh", title="Importância Dados RF")
# Out:
# <AxesSubplot: title={'center': 'Importância Dados RF'}>

# %%
#Feature importance do SVR, duvidoso e sem os nomes
# results = permutation_importance(modelo_svr, x_treino, y_treino, scoring='neg_mean_squared_error')
# print(f'Result: {results}')
# importance = results.importances_mean
# print(f'Importance: {importance}')
# for i,v in enumerate(importance):
#     print('Feature: %0d, Score: %.5f' % (x_treino.columns[i],v)) # Duvidoso, não sabemos a onde das colunas
# plt.bar([x for x in range(len(importance))], importance)

# %%
coefs_lr = pd.DataFrame(modelo_lr.coef_, columns=['Coeficiente'], index = x_treino.columns)
coefs_lr.Coeficiente = coefs_lr.Coeficiente.abs()
coefs_lr['DesvioPadrão'] = x_treino.std(axis=0)
coefs_lr['Importancia'] = (100*coefs_lr['DesvioPadrão']*coefs_lr['Coeficiente'])/coefs_lr['DesvioPadrão']*coefs_lr['Coeficiente'].max()
coefs_lr['Importancia'].plot(kind='barh', title = 'Importância Dados LR')
# Out:
# <AxesSubplot: title={'center': 'Importância Dados LR'}>

# %% [markdown]
# Junção das previsões no dataframe de teste

# %%
df_teste["predicao_xgb"] = modelo_xgb.predict(x_teste)
df_teste["predicao_lr"] = modelo_lr.predict(x_teste)
df_teste["predicao_rf"] = modelo_rf.predict(x_teste)
df_teste["predicao_svr"] = modelo_svr.predict(x_teste)
df_teste
# Out:
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_15788\1728344419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_teste["predicao_xgb"] = modelo_xgb.predict(x_teste)
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_15788\1728344419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_teste["predicao_lr"] = modelo_lr.predict(x_teste)
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_15788\1728344419.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_teste["predicao_rf"] = modelo_rf.predict(x_teste)
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_15788\1728344419.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_teste["predicao_svr"] = modelo_svr.predict(x_teste)
#             data_partida         data_chegada  linha  tempo_viagem  \
# 4080 2019-09-30 23:01:36  2019-09-30 23:29:58  32893          1702
# 5053 2019-09-30 22:40:17  2019-09-30 23:08:08  32893          1671
# 3908 2019-09-30 22:30:04  2019-09-30 22:54:17  32893          1453
# 4343 2019-09-30 21:50:20  2019-09-30 22:21:27  32893          1867
# 4410 2019-09-30 21:38:06  2019-09-30 22:04:36  32893          1590
# ...                  ...                  ...    ...           ...
# 3600 2019-09-03 06:12:43  2019-09-03 06:51:46  32893          2343
# 3819 2019-09-03 06:04:13  2019-09-03 06:51:09  32893          2816
# 4081 2019-09-03 05:47:59  2019-09-03 06:30:14  32893          2535
# 5028 2019-09-03 05:12:48  2019-09-03 05:52:33  32893          2385
# 3756 2019-09-02 23:12:31  2019-09-02 23:42:46  32893          1815
#
#       equipamento  dia_semana  partidaTimeStamp  qtdDiasAno  direcao  \
# 4080        51360           1        1569895296         273        2
# 5053        65409           1        1569894017         273        2
# 3908        51242           1        1569893404         273        2
# 4343        51548           1        1569891020         273        2
# 4410        51691           1        1569890286         273        2
# ...           ...         ...               ...         ...      ...
# 3600         1403           2        1567501963         246        2
# 3819        51209           2        1567501453         246        2
# 4081        51367           2        1567500479         246        2
# 5028        64449           2        1567498368         246        2
# 3756        50232           1        1567476751         245        2
#
#       tipo_dia  turno_dia  chegadaTimeStamp  hora  hora_dia  predicao_xgb  \
# 4080         1          4        1569896998   NaN        23   1716.796387
# 5053         1          4        1569895688   NaN        22   1822.618652
# 3908         1          4        1569894857   NaN        22   1822.618652
# 4343         1          4        1569892887   NaN        21   1822.618652
# 4410         1          4        1569891876   NaN        21   1822.618652
# ...        ...        ...               ...   ...       ...           ...
# 3600         1          2        1567504306   NaN         6   2808.860840
# 3819         1          2        1567504269   NaN         6   2808.860840
# 4081         1          2        1567503014   NaN         5   2601.530518
# 5028         1          2        1567500753   NaN         5   2601.530518
# 3756         1          4        1567478566   NaN        23   1716.796387
#
#       predicao_lr  predicao_rf  predicao_svr
# 4080  2746.759381  1868.724451   2606.462938
# 5053  2722.074047  1940.110263   2606.462938
# 3908  2722.101253  1940.110263   2606.462938
# 4343  2697.464960  1905.204070   2606.462938
# 4410  2697.497536  1905.204070   2606.462938
# ...           ...          ...           ...
# 3600  2664.321952  3156.178513   2606.462938
# 3819  2664.344586  3156.178513   2606.462938
# 4081  2639.645716  2869.778280   2606.462938
# 5028  2639.739405  2869.778280   2606.462938
# 3756  2854.096835  1868.724451   2606.462938
#
# [1581 rows x 18 columns]

# %% [markdown]
# Cálculo das métricas

# %%
RRSE_xgb = np.sqrt(sum((df_teste["tempo_viagem"] - df_teste["predicao_xgb"]) ** 2) / sum((df_teste["tempo_viagem"] - np.mean(df_teste["tempo_viagem"])) ** 2))
RMSE_xgb = mtr.mean_squared_error(df_teste["tempo_viagem"], df_teste["predicao_xgb"], squared=False) 

RRSE_rf = np.sqrt(sum((df_teste["tempo_viagem"] - df_teste["predicao_rf"]) ** 2) / sum((df_teste["tempo_viagem"] - np.mean(df_teste["tempo_viagem"])) ** 2))
RMSE_rf = mtr.mean_squared_error(df_teste["tempo_viagem"], df_teste["predicao_rf"], squared=False) 

RRSE_svr = np.sqrt(sum((df_teste["tempo_viagem"] - df_teste["predicao_svr"]) ** 2) / sum((df_teste["tempo_viagem"] - np.mean(df_teste["tempo_viagem"])) ** 2))
RMSE_svr = mtr.mean_squared_error(df_teste["tempo_viagem"], df_teste["predicao_svr"], squared=False) 

RRSE_lr = np.sqrt(sum((df_teste["tempo_viagem"] - df_teste["predicao_lr"]) ** 2) / sum((df_teste["tempo_viagem"] - np.mean(df_teste["tempo_viagem"])) ** 2))
RMSE_lr = mtr.mean_squared_error(df_teste["tempo_viagem"], df_teste["predicao_lr"], squared=False) 

metrics = pd.DataFrame(np.array([
        [RRSE_xgb, RRSE_rf, RRSE_svr, RRSE_lr],
        [RMSE_xgb, RMSE_rf, RMSE_svr, RMSE_lr]
    ]),columns=['XGBoosting','Random Forest','Support Vector Regression','Linear Regression'], index=['RRSE','RMSE'])
metrics
# Out:
#       XGBoosting  Random Forest  Support Vector Regression  Linear Regression
# RRSE    0.977484       1.032403                   1.008383           1.010716
# RMSE  915.544459     966.983594                 944.486156         946.670627

# %%
dfi.export(metrics, "Images/metrics_33642_s_qtdD.png")
